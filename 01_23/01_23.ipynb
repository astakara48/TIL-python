# %%
코랩(colab) : 주피터를 구글서버에서 동작
-> 웹 브라우저만 설치되어 있으면 어디서든 주피터 노트북 이용 가능, 공유, 데이터 분석 패키지 설치 별도로 필요 x
-> GPU사용
-> 구글 로그인 ->
# Out:
# 38460.0

# %%
import matplotlib
from matplotlib import font_manager, rc
import platform
if platform.system()=="Windows":
    font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus']=False

import warnings
warnings.filterwarnings("ignore")

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
import matplotlib as mpl
#import matplotlib.pyplot as plt
import matplotlib.pylab as plt
#pylab : 수치해석 S/W -> 시각화 명령 -> 그대로 사용 가능

# %%
# %matplotlib inline
# 노트북 내부에 이미지 출력

# %%
# 선(line plot)
plt.title('plot')
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title('plot')
plt.plot([10,20,30,40],[1,4,9,16], 'rD:')
plt.xlabel("x axis")
plt.ylabel('y axis')
plt.show()

# %%
plt.title('plot')
plt.plot([10,20,30,40],[1,4,9,16], c='b', lw=5, ls='--', marker="o", ms=15)
plt.xlabel("x axis")
plt.ylabel('y axis')
plt.show()

# %%
# 틱설정:플롯에서 축의 표시 지점
# xticks, yticks

# %%
x=np.linspace(-np.pi,np.pi,256)
#np.pi
c=np.cos(x)
plt.plot(x,c)
plt.xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi])
plt.yticks([-1,0,1])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
t=np.arange(0,5,0.2)
plt.plot(t,t,'r--',t,0.5*t**2,'bs:')
# Out:
# [<matplotlib.lines.Line2D at 0x244b3446748>,
#  <matplotlib.lines.Line2D at 0x244b34468c8>]

# %%
x=np.linspace(-np.pi,np.pi,256)
#np.pi
c,s=np.cos(x), np.sin(x)
plt.plot(x,c,ls='--',label='cosine')
plt.plot(x,s,ls='--',label='sin',c='r')
plt.legend(loc=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# figure : 그림을 그릴때 사용할 도화지 
# axes : 하나의 플롯
# axis : 하나의 축
# ex) 종이(figure)를 반으로 접어서(axes) 각 axes에 2차원 그림을 출력(axis)

# %%
np.random.seed(0)
f1=plt.figure(figsize=(10,2))
plt.plot(np.random.rand(100))
plt.show()

# %%
# subplot(2,1,1) # 2행 1열에 위쪽
# subplot(2,1,2) # 2행 1열에 아래쪽
x1=np.linspace(0.0,5.0)
x1
x2=np.linspace(0.0,2.0)
y1=np.cos(2*np.pi*x1)*np.exp(-x1)
y2=np.cos(2*np.pi*x2)

ax1=plt.subplot(2,1,1)
plt.plot(x1,y1,'yo-')
plt.title("table1")

ax2=plt.subplot(2,1,2)
plt.plot(x2,y2,'r.-')
plt.title("table2")

plt.tight_layout()

# %%
# fig, axes=plt.subplots(2,2)

# %%
# 바차트
y=[2,3,1]
x=np.arange(len(y))#[0,1,2]
plt.bar(x,y)
plt.xticks(x,['X','Y','Z'])
plt.xlabel('가나다')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.linspace(0.1,2*np.pi,10)
plt.stem(x,np.cos(x),"-.")
plt.show()

# %%
labels=['취업','결혼','출산','건강']
sizes=[15,30,45,10]
colors=['yellow','gold','skyblue','lightcoral']
ex=(0.1,0,0,0)
plt.pie(sizes, explode=ex, autopct="%.1f%%",labels=labels, colors=colors, shadow=True, startangle=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# hist:히스토그램
x=np.random.randn(100)
arr, bins, patches=plt.hist(x,bins=10)
plt.show
# arr : 각 데이터 구간의 데이터 건수
# bins : 나누어진 구간
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# 스캐터플롯 : 두 실수 데이터 집합에서 상관관계를 나타낼때 사용
x=np.random.normal(0,1,100)
y=np.random.normal(0,1,100)
plt.scatter(x,y)
plt.show()
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
w=np.random.randn(30)
x=np.random.randn(30)
y=np.random.randn(30)
z=np.pi*(10*np.random.rand(30))**2
plt.scatter(w,x,c=y,s=z)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from sklearn.datasets import load_digits

# %%
digits=load_digits()
x=digits.images[0]
x
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.imshow(x, cmap=plt.cm.bone_r)

# %%
import seaborn as sns

# %%
anscombe=sns.load_dataset("anscombe")
anscombe
# 데이터를 통계치로 해보면 제대로 나오지만 시각화를 하면 제대로 안나옴 -> 데이터를 시각화를 할 필요가 있다는 근거가 되는 자료
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
anscombe['dataset'].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
d1=anscombe[anscombe['dataset']=='I']
#'I', 'II', 'III', 'IV'
d2=anscombe[anscombe['dataset']=='II']
d3=anscombe[anscombe['dataset']=='III']
d4=anscombe[anscombe['dataset']=='IV']

plt.plot(d1['x'],d1['y'],'o')

# %%
fig=plt.figure()
axes1=fig.add_subplot(2,2,1)
axes2=fig.add_subplot(2,2,2)
axes3=fig.add_subplot(2,2,3)
axes4=fig.add_subplot(2,2,4)

# %%
axes1.plot(d1['x'],d1['y'],'o')
axes2.plot(d2['x'],d2['y'],'o')
axes3.plot(d3['x'],d3['y'],'o')
axes4.plot(d4['x'],d4['y'],'o')

fig

# %%
axes1.set_title('dataset1')
axes2.set_title('dataset2')
axes3.set_title('dataset3')
axes4.set_title('dataset4')
fig.suptitle("Anscome data")
fig.tight_layout()
fig

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig=plt.figure()
axes1=fig.add_subplot(1,1,1)
axes1

# %%
axes1.hist(tips['total_bill'],bins=6)
fig
# 첫번째꺼는 빈도
# 두번째꺼는 tip 금액

# %%
scPlot=plt.figure()
axes1=scPlot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'])

# %%
boxPlot=plt.figure()
axes1=boxPlot.add_subplot(1,1,1)
axes1.boxplot(tips[tips[tips['sex']=='Female']['tip'],tips[tips['sex']=='Male']['tip']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-178-cf1d905446b1> in <module>
#       1 boxPlot=plt.figure()
#       2 axes1=boxPlot.add_subplot(1,1,1)
# ----> 3 axes1.boxplot(tips[tips[tips['sex']=='Female']['tip'],tips[tips['sex']=='Male']['tip']])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0      1.01
# 4      3.61
# 11     5.00
# 14     3.02
# 16     1.67
#        ...
# 226    2.00
# 229    2.88
# 238    4.67
# 240    2.00
# 243    3.00
# Name: tip, Length: 87, dtype: float64, 1      1.66
# 2      3.50
# 3      3.31
# 5      4.71
# 6      2.00
#        ...
# 236    1.00
# 237    1.17
# 239    5.92
# 241    2.00
# 242    1.75
# Name: tip, Length: 157, dtype: float64)' is an invalid key

# %%
axes1.boxplot([tips[tips['sex']=='Female']['tip'],tips[tips['sex']=='Male']['tip']],labels=["Female","Male"])
boxPlot

# %%
tips['sex']
# Female=>0, Male=>1
tips['sex_color']=tips['sex'].map({'Female':0,'Male':1})
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_color
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0
# 1         10.34  1.66    Male     No   Sun  Dinner     3         1
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1
# 242       17.82  1.75    Male     No   Sat  Dinner     2         1
# 243       18.78  3.00  Female     No  Thur  Dinner     2         0
#
# [244 rows x 8 columns]

# %%
def enc(s):
    if s=='Female':
        return 0
    else:
        return 1

tips['sex_color']=tips['sex'].apply(enc)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_color
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0
# 1         10.34  1.66    Male     No   Sun  Dinner     3         1
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1
# 242       17.82  1.75    Male     No   Sat  Dinner     2         1
# 243       18.78  3.00  Female     No  Thur  Dinner     2         0
#
# [244 rows x 8 columns]

# %%
sPlot=plt.figure()
axes1=sPlot.add_subplot(1,1,1)
axes1.scatter(x=tips['total_bill'],y=tips['tip'],s=tips['size']*10,c=tips['sex_color'], alpha=0.5)

# %%
import seaborn as sns

# %%
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'], kde=True, rug=True) 
# kde - 밀집도(그래프)와 히스토그램 같이 출력할지? / rug : 데이터 밀집되어 있는 정도
# distplot은 seaborn에서 히스토그램을 그릴때 사용하는 함수

# %%
ax=plt.subplots()
sns.countplot('day',data=tips)
