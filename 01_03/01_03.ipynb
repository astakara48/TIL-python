# %%
"""
로그인 하는 절차 
login_proc.php
1) 주소 : http://www.hanbit.co.kr/index.html
2) 로그인 주소 : https://www.hanbit.co.kr/member/login.html
3) m_id <- test, m_passwd <- 1234 전달한 후 로그인 처리 (x~~~.php)
  => 처리 결과는 2가지 : 로그인 성공 // 로그인 실패
4) 사용자페이지 http://www.hanbit.co.kr/myhanbit/myhanbit.html


1. client : www.hanbit.co.kr 입력
2. server : http://ww.hanbit.co.kr/index.html 을 client에게 전달(정상신호 : 200 전달)
                                                             (비정상 신호 
                                                              1) 잘못된 주소 입력 - 40x... 404 402 등등
                                                              2) 서버내부 오류 : 50x )
3. client : web browser가 http://www.hanbit.co.kr/index.html 해석 -> 결과 화면 출력
"""

# %%
# 로그인 모듈
import requests
from bs4 import BeautifulSoup

# %%
USER="astakara"
PASS="~Cjswo041!"

# %%
# session(server와 client간 연결) 시작하기
session=requests.session() # 승차권
login_info={"m_id":USER ,"m_passwd":PASS }
# login_proc.php 주소
url_login="https://www.hanbit.co.kr/member/login_proc.php"

# %%
res=session.post(url_login, data=login_info)
# 로그인 처리하는 부분 ㅇㅅㅇ
# post 방식 -> 정보를 안보여 줌 // get 방식 -> 정보를 보여줌
# 보안적 측면에서 차이가 있음
res.raise_for_status() # 에러가 발생했을 경우 예외상황을 출력
                       # 이 경우 login_proc9.php 라는 문서가 없으므로 404 에러가 발생함
                       # 접속을 하는 부분 바로 아래에 오게 할 것

# %%
res

# %%
res=session.get("http://www.hanbit.co.kr/myhanbit/myhanbit.html")
res.raise_for_status()

# %%
soup=BeautifulSoup(res.text, "html.parser")
mileage=soup.select_one("#container > div > div.sm_mymileage > dl.mileage_section1 > dd > span").get_text()
soup=BeautifulSoup(res.text, "html.parser")
ecoin=soup.select_one("#container > div > div.sm_mymileage > dl.mileage_section2 > dd > span").get_text()
print("마일리지:"+mileage)
print("이코인:"+ecoin)

# %%
# 웹 브라우저를 이용한 스크래핑
# Selenium : 웹 브라우저를 조작 도구
# Phantomjs : 화면없이  명령줄에서 이용할 수 있는 웹 브라우저
# Phantomjs를 이용하여 사이트 탐색(이동)
# selenium을 이용하여 해당 사이트에서 자동으로 url 열기, 클릭, 스크롤, 문자 입력 가능, 화면 캡쳐 등의 작업을 수행


# 환경 변수 설명
#  - a 폴터 : abc.exe 가 있는데
#  - b 폴더에서 abc를 실행하면 -> 안됨
#   => a폴더를 PATH에 추가하면 다른 경로에서도 a폴더에 있는 파일을 실행가능하게 해줌

# %%
"""
1. 아나콘다 프롬프트 : pip install selenium
    - 자동으로 url 읽기, 클릭, 스크롤, 문자 입력 가능, 화면 캡쳐
2. Phantomjs를 이용하여 사이트 탐색(이동)
   selenium을 이용하여 해당 사이트에서 자동으로 url 열기, 클릭, 스크롤, 문자 입력 가능, 화면 캡쳐 등의 작업을 수행
"""

# %%
from selenium import webdriver
url="http://www.naver.com"
#phantomJS 드라이버 추출
browser = webdriver.PhantomJS()
browser.implicitly_wait(3) # 대기 하는 명령어, 3 쓰면 3초 정도 쉬었다가 연결
# url 읽기
browser.get(url)
# 화면 캡쳐
browser.save_screenshot("myshot.png")
# 브라우저 종료
browser.quit()
# Out:
# C:\Users\student\Anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
import urllib.request as req
page = req.urlopen("https://www.rottentomatoes.com/")
page
doc=page.read()
soup=BeautifulSoup(d, "html.parser")
movies=soup.find(id="homepage-top-box-office")
movies
# Out:
# <div class="listings" id="homepage-top-box-office">
# <a class="pull-right showtimesLink" href="/showtimes/">Get Tickets</a>
# <h2>Top Box Office</h2>
# <table class="movie_list" id="Top-Box-Office">
# <tr class="">
# <td class="left_col">
# <a href="/m/star_wars_the_rise_of_skywalker">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">54%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/star_wars_the_rise_of_skywalker">Star Wars: The Rise of Skywalker</a>
# </td>
# <td class="right_col right">
# <a href="/m/star_wars_the_rise_of_skywalker">$72M</a>
# </td>
# </tr>
# <tr class="">
# <td class="left_col">
# <a href="/m/jumanji_the_next_level">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">71%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/jumanji_the_next_level">Jumanji: The Next Level</a>
# </td>
# <td class="right_col right">
# <a href="/m/jumanji_the_next_level">$35.4M</a>
# </td>
# </tr>
# <tr class="">
# ...

# %%
movies_list=movies.find_all("td", class_="middle_col")
for movie in movies_list:
    print(movie.get_text())
    print("https://rottentomatoes.com"+movie.find("a").get("href"))
# Out:
# Star Wars: The Rise of Skywalker
#
# https://rottentomatoes.com/m/star_wars_the_rise_of_skywalker
#
# Jumanji: The Next Level
#
# https://rottentomatoes.com/m/jumanji_the_next_level
#
# Little Women
#
# https://rottentomatoes.com/m/little_women_2019
#
# Frozen II
#
# https://rottentomatoes.com/m/frozen_ii
#
# Spies in Disguise
#
# https://rottentomatoes.com/m/spies_in_disguise
#
# Knives Out
#
# https://rottentomatoes.com/m/knives_out
#
# Uncut Gems
#
# https://rottentomatoes.com/m/uncut_gems
#
# Cats
#
# https://rottentomatoes.com/m/cats_2019
#
# Bombshell
#
# https://rottentomatoes.com/m/bombshell_2019
#
# Richard Jewell
#
# https://rottentomatoes.com/m/richard_jewell

# %%
#question-summary-59573576 > div.summary > h3 > a
#question-summary-59573537 > div.summary > h3 > a
# https://stackoverflow.com/questions/tagged/python?tab=newest&page=1&pagesize=15
# https://stackoverflow.com/questions/tagged/python?tab=newest&page=2&pagesize=15
# https://stackoverflow.com/questions/tagged/python?tab=newest&page=3&pagesize=15

# %%
import requests
url="https://stackoverflow.com/questions/tagged/python"
response=requests.get(url)
soup=BeautifulSoup(response.text, "html.parser")
links=[]
for link in soup.select("div.question-summary h3 a"):
    # print("https://stackoverlfow.com"+link.attrs["href"])
    links.append(link.attrs["href"])
for link in links:
    url="https://stackoverflow.com"+link
    response=requests.get(url)
    text=response.text
    soup=BeautifulSoup(text, "html.parser")
    print("Question\n")
    for x in soup.select("div.postcell div.post-text p"):
        print(x.text)
    print("Answer\n")
    for x in soup.select("div.answercell div.post-text p"):
        print(x.text)
    print("="*40, "\n")
    
    
#     print("Question\n")
    
#     print("\nAnswer\n")
    
#     print("="*50,"\n")
# Out:
# Question
#
# I want to convert the '.csv' files to the '.hyper' file using python.
# so I found pantab. but when I run it, I’ve got a unicode error message.
# example
# error code
# Could you please explain me how to fix this?
# Answer
#
# ...
#
# Question
#
# I draw the qq plot multiple regression and I got below graph. and can I know someone why there have unusual two points under red line. and is that points effect for my model?
#
# Answer
#
# ...
#
# Question
#
# (Python Code)
# I am not able to get linked campaignIDs from different bing accountids
# I have gone  through documentation extensively.Please help
# P.S Different bing ads accountIDs means With one account there are multiple bing ads account linked
# Answer
#
# ...
#
# Question
#
# I have this script that gives me the location of an IP address that I found on github, but when I run the script i just get a blank terminal. It should show up with a country name, state name, and city name. How could I fix this? Here is the code
# Answer
#
# ...
#
# ...
